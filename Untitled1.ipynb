# %% [markdown]
# <a href="https://colab.research.google.com/github/jayalaxmikonchady-web/chaithra123/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
max=lambda a,b:a if(a>b) else b
__builtins__.print(max(4,5))
x=lambda a:a+1
__builtins__.print(x(5))
x=lambda a,b,c:a+b+c
__builtins__.print(x(5,6,2))
# Out:
# 5
# 6
# 13

# %%
def add4(x):
     return x+4
list1=[4,6,7,8,9]
list2=list(map(add4,list1))
__builtin__.print(list2)
# Out:
# [8, 10, 11, 12, 13]

# %%
def start_with_A(s):
   return s[0]=="A"
fruit=["Apple","banana","pear","apricot","orange"]
map_object=map(start_with_A,fruit)
__builtins__.print(list(map_object))
# Out:
# [True, False, False, False, False]

# %%
def evenodd(x):
  if x%2==0:
    return True
  else:
    return False
list1=[4,5,6,8,9]
evenlist=list(filter(evenodd,list1))
__builtins__.print(evenlist)
# Out:
# [4, 6, 8]

# %%
def start_with_A(s):
   return s[0]=="A"
fruit=["Apple","banana","pear","Apricot","orange"]
filter_object=filter(start_with_A,fruit)
__builtins__.print(list(filter_object))
# Out:
# ['Apple', 'Apricot']
