# %% [markdown]
# <a href="https://colab.research.google.com/github/jayalaxmikonchady-web/chaithra123/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data={
    'first':['aryan','rohan','riya','yash','siddini'],
    'lastname':['singh','agarwal','shah','batia','khan'],
    'type':['full_time employee','inter','full_time employee','part_time employee','full_time employee'],
    'department':['administration','technical','administration','technical','technical'],
    'yoe':[2,3,5,7,6],
    'salary':[20000,5000,10000,20000,0]
    }
df=pd.DataFrame(data)
__builtins__.print(df)
table=pd.pivot_table(df,index=['type','department'], values='salary')
__builtins__.print(table)
table1=pd.pivot_table(df,index=['type'],values='salary')
__builtins__.print(table1)
table2=pd.pivot_table(df,index=['type','department'],values='salary')
__builtins__.print(table2)
table3=pd.pivot_table(df,index=['type'],values='salary',aggfunc=['std'])
__builtins__.print(table3)
# Out:
#      first lastname                type      department  yoe  salary
# 0    aryan    singh  full_time employee  administration    2   20000
# 1    rohan  agarwal               inter       technical    3    5000
# 2     riya     shah  full_time employee  administration    5   10000
# 3     yash    batia  part_time employee       technical    7   20000
# 4  siddini     khan  full_time employee       technical    6       0
#                                     salary
# type               department
# full_time employee administration  15000.0
#                    technical           0.0
# inter              technical        5000.0
# part_time employee technical       20000.0
#                      salary
# type
# full_time employee  10000.0
# inter                5000.0
# part_time employee  20000.0
#                                     salary
# type               department
# full_time employee administration  15000.0
#                    technical           0.0
# ...
